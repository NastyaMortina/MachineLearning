# %% [markdown]
# ## Домашняя работа №1
# Мортина Анастасия 3821Б1ФИ3
# ### Описание задачи
# Набор данных о бронировании отелей.
# Перед нами стоит задача классификации. По данным датасета нужно предсказать, отменит ли клиент бронировние номера в отеле или подтвердит его.

# %%
#Импортируем необходимые библиотеки
import sklearn
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Чтение данных

# %%
data = pd.read_csv("C:\\Users\\Анастасия\\.ipynb_checkpoints\\Hotel Reservations.csv")

# %% [markdown]
# ### Вывод данных

# %%
data.shape
# Out:
# (36275, 19)

# %%
data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
#Выведем информацию о первых пяти строках таблицы
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
#Выведем информацию о последних пяти строках таблицы
data.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %%
#Выводим названия столбцов
print(data.columns)
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
#Выводим информацию обо всех столбцах таблицы
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# Опишем столбцы:
#
# -Booking_ID: уникальный идентификатор каждого бронирования
#
# -no_of_adults: Количество взрослых
#
# -no_of_children: Количество детей
#
# -no_of_weekend_nights: Количество ночей в выходные дни (суббота или воскресенье), в течение которых гость останавливался или забронировал проживание в отеле
#
# -no_of_week_nights: Количество ночей в будние дни (с понедельника по пятницу), в течение которых гость остановился или забронировал проживание в отеле
#
# -type_of_meal_plan: Тип плана питания, забронированного клиентом:
#
# -required_car_parking_space: Требуется ли клиенту парковочное место? (0 - Нет, 1 - Да)
#
# -room_type_reserved: Тип номера, забронированного клиентом. Значения шифруются (кодируются) компанией INN Hotels.
#
# -lead_time: Количество дней между датой бронирования и датой прибытия
#
# -arrival_year: Год прибытия, дата
#
# -arrival_month: Месяц даты прибытия
#
# -arrival_date: Число месяца
#
# -market_segment_type: Обозначение сегмента рынка.
#
# -repeated_guest: Является ли клиент постоянным гостем? (0 - Нет, 1 - Да)
#
# -no_of_previous_cancellations: количество предыдущих бронирований, которые были отменены клиентом до текущего бронирования.
#
# -no_of_previous_bookings_not_canceled: Количество предыдущих бронирований, не отмененных клиентом до текущего бронирования
#
# -avg_price_per_room: Средняя цена за сутки бронирования; Цены на номера динамичные. (в евро)
#
# -no_of_special_requests: Общее количество специальных пожеланий, сделанных клиентом (например, высокий этаж, вид из комнаты и т. д.)
#
# -booking_status: Флажок, указывающий, было ли отменено бронирование или нет.

# %%
#Удалим первый столбец Booking_ID, так как он не несет никакой смысловой нагрузки и является всего лишь идентификатором
data = data.drop(labels = "Booking_ID", axis = 1)

# %%
#Теперь таблица выглядит так:
data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1         48
#
# ...

# %% [markdown]
# ### Обработка пропущенных значений

# %%
data.isnull().sum()
# Out:
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %% [markdown]
# Методом data.isnull().sum() проверяем наличие пропущенных значений. Метод выводит количество пропущенных значений для каждого столбца. В моём случае видно, что все значения равны 0, то есть пропущенных значений нет.

# %% [markdown]
# ### Визуализация данных

# %%
sns.pairplot(data)

# %%
#Вычисляем и визуализируем корреляционную матрицу
corr = data.corr(numeric_only=True)
print(corr)
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# required_car_parking_space                0.011429        0.034244
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# ...

# %%
sns.heatmap(corr, square=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm')
# Out:
# <Axes: >

# %%
data.corr(numeric_only=True)
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# required_car_parking_space                0.011429        0.034244
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# ...

# %% [markdown]
# По данной матрице можно сделать вывод, что почти все признаки зависимы друг от друга. Для примера визуализируем это на графиках

# %%
plt.plot(data['no_of_adults'], data['lead_time'], 'o', alpha = 0.05)
plt.xlabel('no_of_adults')
plt.ylabel('lead_time')
plt.title('no_of_adults vs lead_time')
# Out:
# Text(0.5, 1.0, 'no_of_adults vs lead_time')

# %%
plt.plot(data['no_of_adults'], data['avg_price_per_room'], 'o', alpha = 0.05)
plt.xlabel('no_of_adults')
plt.ylabel('avg_price_per_room')
plt.title('no_of_adults vs avg_price_per_room')
# Out:
# Text(0.5, 1.0, 'no_of_adults vs avg_price_per_room')

# %%
#Визуализируем "Ящик с усами" на примере одного из признаков
plt.figure(figsize=(3, 4))
sns.boxplot(y="avg_price_per_room", data = data)
plt.title('Ящик с усами')
plt.show()
pass

# %%
plt.figure(figsize=(3, 4))
sns.boxplot(y="lead_time", data = data)
plt.title('Ящик с усами')
plt.show()
pass

# %% [markdown]
# ### Обработка категориальных признаков

# %%
#Разделим категориальные и числовые признаки
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type', 'booking_status']
# ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests']

# %%
#Выведем все уникальные значения для каждого категориального признака
for c in categorical_columns:
    print(f"{c}: {data[c].unique()}")
# Out:
# type_of_meal_plan: ['Meal Plan 1' 'Not Selected' 'Meal Plan 2' 'Meal Plan 3']
# room_type_reserved: ['Room_Type 1' 'Room_Type 4' 'Room_Type 2' 'Room_Type 6' 'Room_Type 5'
#  'Room_Type 7' 'Room_Type 3']
# market_segment_type: ['Offline' 'Online' 'Corporate' 'Aviation' 'Complementary']
# booking_status: ['Not_Canceled' 'Canceled']

# %%
for category_col in ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type', 'booking_status']:
    data[category_col] = data[category_col].astype('category')

# %%
data['type_of_meal_plan'].dtype
# Out:
# CategoricalDtype(categories=['Meal Plan 1', 'Meal Plan 2', 'Meal Plan 3', 'Not Selected'], ordered=False, categories_dtype=object)

# %%
data.describe(include=['category'])
# Out:
#        type_of_meal_plan room_type_reserved market_segment_type booking_status
# count              36275              36275               36275          36275
# unique                 4                  7                   5              2
# top          Meal Plan 1        Room_Type 1              Online   Not_Canceled
# freq               27835              28130               23214          24390

# %%
#Обрабатываем первое значение
unique_values = data['type_of_meal_plan'].unique()
print(unique_values)
# Out:
# ['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3']
# Categories (4, object): ['Meal Plan 1', 'Meal Plan 2', 'Meal Plan 3', 'Not Selected']

# %%
#Преобразовываем значение 
data['type_of_meal_plan'] = data['type_of_meal_plan'].map({'Meal Plan 1': 0, 'Not Selected': 1, 'Meal Plan 2':2, 'Meal Plan 3':3})

# %%
data['type_of_meal_plan']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 36270    0
# 36271    0
# 36272    0
# 36273    1
# 36274    0
# Name: type_of_meal_plan, Length: 36275, dtype: category
# Categories (4, int64): [0, 2, 3, 1]

# %%
data.head(2)
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0                 0                           0        Room_Type 1        224
# 1                 1                           0        Room_Type 1          5
#
#    arrival_year  arrival_month  arrival_date market_segment_type  \
# 0          2017             10             2             Offline
# 1          2018             11             6              Online
#
#    repeated_guest  no_of_previous_cancellations  \
# 0               0                             0
# 1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# ...

# %%
unique_values = data['room_type_reserved'].unique()
print(unique_values)
# Out:
# ['Room_Type 1', 'Room_Type 4', 'Room_Type 2', 'Room_Type 6', 'Room_Type 5', 'Room_Type 7', 'Room_Type 3']
# Categories (7, object): ['Room_Type 1', 'Room_Type 2', 'Room_Type 3', 'Room_Type 4', 'Room_Type 5', 'Room_Type 6', 'Room_Type 7']

# %%
data['room_type_reserved'] = data['room_type_reserved'].map({'Room_Type 1': 0, 'Room_Type 2': 1, 'Room_Type 3':2, 'Room_Type 4':3, 'Room_Type 5':4, 'Room_Type 6':5, 'Room_Type 7':6})

# %%
data['room_type_reserved']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 36270    3
# 36271    0
# 36272    0
# 36273    0
# 36274    0
# Name: room_type_reserved, Length: 36275, dtype: category
# Categories (7, int64): [0, 1, 2, 3, 4, 5, 6]

# %%
data.head(2)
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0                 0                           0                  0        224
# 1                 1                           0                  0          5
#
#    arrival_year  arrival_month  arrival_date market_segment_type  \
# 0          2017             10             2             Offline
# 1          2018             11             6              Online
#
#    repeated_guest  no_of_previous_cancellations  \
# 0               0                             0
# 1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# ...

# %%
unique_values = data['market_segment_type'].unique()
print(unique_values)
# Out:
# ['Offline', 'Online', 'Corporate', 'Aviation', 'Complementary']
# Categories (5, object): ['Aviation', 'Complementary', 'Corporate', 'Offline', 'Online']

# %%
data['market_segment_type'] = data['market_segment_type'].map({'Aviation': 0, 'Complementary': 1, 'Corporate':2, 'Offline':3, 'Online':4})

# %%
data['market_segment_type']
# Out:
# 0        3
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 36270    4
# 36271    4
# 36272    4
# 36273    4
# 36274    3
# Name: market_segment_type, Length: 36275, dtype: category
# Categories (5, int64): [0, 1, 2, 3, 4]

# %%
data.head(2)
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0                 0                           0                  0        224
# 1                 1                           0                  0          5
#
#    arrival_year  arrival_month  arrival_date market_segment_type  \
# 0          2017             10             2                   3
# 1          2018             11             6                   4
#
#    repeated_guest  no_of_previous_cancellations  \
# 0               0                             0
# 1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# ...

# %%
unique_values = data['booking_status'].unique()
print(unique_values)
# Out:
# ['Not_Canceled', 'Canceled']
# Categories (2, object): ['Canceled', 'Not_Canceled']

# %%
data['booking_status'] = data['booking_status'].map({'Canceled': 0, 'Not_Canceled': 1})

# %%
data['booking_status']
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 36270    1
# 36271    0
# 36272    1
# 36273    0
# 36274    1
# Name: booking_status, Length: 36275, dtype: category
# Categories (2, int64): [0, 1]

# %%
data.head(2)
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0                 0                           0                  0        224
# 1                 1                           0                  0          5
#
#    arrival_year  arrival_month  arrival_date market_segment_type  \
# 0          2017             10             2                   3
# 1          2018             11             6                   4
#
#    repeated_guest  no_of_previous_cancellations  \
# 0               0                             0
# 1               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# ...

# %%
print(data.head())
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0                 0                           0                  0        224
# 1                 1                           0                  0          5
# 2                 0                           0                  0          1
# 3                 0                           0                  0        211
# 4                 1                           0                  0         48
#
# ...

# %%
data
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 36270             3               0                     2                  6
# 36271             2               0                     1                  3
# 36272             2               0                     2                  6
# 36273             2               0                     0                  3
# 36274             2               0                     1                  2
#
# ...

# %%
data.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
corr = data.corr(numeric_only=True)
sns.heatmap(corr, square=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Обучающая и тестовая выборки

# %%
#Берём целевой признак
X = data.drop (["booking_status"], axis=1)
y = data["booking_status"]

# %%
#Разделяем данные на выборки
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

N_train, _ = X_train.shape
N_test,  _ = X_test.shape

N_train, N_test
# Out:
# (27206, 9069)

# %% [markdown]
# ### Классификация и вычисление ошибок

# %% [markdown]
# Используем алгоритм K-ближайших соседей (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, mean_squared_error

#По-умолчанию k = 5
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
y_train_pred = knn_model.predict(X_train)
y_test_pred = knn_model.predict(X_test)
print("Accuracy score: Train: {:.2f}%, Test: {:.2f}%".format(100 * accuracy_score(y_train, y_train_pred), 100 * accuracy_score(y_test, y_test_pred)))
print("MSE: Train: {}, Test: {}".format(mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
# Out:
# Accuracy score: Train: 86.58%, Test: 80.89%
# MSE: Train: 0.13416158200396971, Test: 0.19109052817289668

# %%
#k = 10
knn_model = KNeighborsClassifier(n_neighbors=10)
knn_model.fit(X_train, y_train)
y_train_pred = knn_model.predict(X_train)
y_test_pred = knn_model.predict(X_test)
print("Accuracy score: Train: {:.2f}%, Test: {:.2f}%".format(100 * accuracy_score(y_train, y_train_pred), 100 * accuracy_score(y_test, y_test_pred)))
print("MSE: Train: {}, Test: {}".format(mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
# Out:
# Accuracy score: Train: 83.39%, Test: 79.78%
# MSE: Train: 0.1661398220980666, Test: 0.20222736795677582

# %%
#k = 15
knn_model = KNeighborsClassifier(n_neighbors=15)
knn_model.fit(X_train, y_train)
y_train_pred = knn_model.predict(X_train)
y_test_pred = knn_model.predict(X_test)
print("Accuracy score: Train: {:.2f}%, Test: {:.2f}%".format(100 * accuracy_score(y_train, y_train_pred), 100 * accuracy_score(y_test, y_test_pred)))
print("MSE: Train: {}, Test: {}".format(mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
# Out:
# Accuracy score: Train: 82.36%, Test: 80.37%
# MSE: Train: 0.17635815628905388, Test: 0.1962730179733157

# %% [markdown]
# Наибольшую точность на обучающей выюорке 86.58% и тестовой выборке 80.89% показал KNN алгоритм при k = 15.

# %%
#Построим матрицк ошибок
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, cmap=plt.cm.Blues)
disp.plot()
pass

# %% [markdown]
# Проведем классификацию при помощи алгоритма Random forest.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)
print("Accuracy score: Train: {:.2f}%, Test: {:.2f}%".format(100 * accuracy_score(y_train, y_train_pred), 100 * accuracy_score(y_test, y_test_pred)))
print("MSE: Train: {}, Test: {}".format(mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
# Out:
# Accuracy score: Train: 99.42%, Test: 90.54%
# MSE: Train: 0.00580754245387047, Test: 0.09460800529275554

# %% [markdown]
# Алгоритм Random forest показывает себя гораздо лучше на выборках, чем KNN, в особенности на обучающей выборке.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Процент правильно предсказанных значений методом k ближайших соседей выше 82% на обучающей и и 89 на тестовой выборках - это приемлимый показатель. По результатам вычислений можно видеть, что при 5 ближайщих соседях метод дает налучший результат - ошибка на тестовой выборке составляет 19.1%, а на обучающей 13.4%. Исходя из таких результатов можно сказать, что модель не переобучилась.

# %% [markdown]
# Общий вывод:
# В данной лабораторной работе был проведен анализ датасета. Мы прочитали, обработали, взуализировали данные. Обработали пропущенные значения и категориальные признаки, обучили модель, классифицировали её и вывели ошибки, результаты анализировали. То есть создали модель, которая предсказывает отменит ли клиент бронировние номера в отеле или подтвердит его.
